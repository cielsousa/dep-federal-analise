# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/vboxuser/miniconda3/envs/etl/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/vboxuser/miniconda3/envs/etl/lib/python3.10/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vboxuser/miniconda3/envs/etl/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vboxuser/miniconda3/envs/etl/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vboxuser/miniconda3/envs/etl/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/vboxuser/miniconda3/envs/etl/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
# ===Base de dados===

# Informações sobre cálculos, etc.
# https://www.tre-ce.jus.br/comunicacao/noticias/2022/Agosto/entenda-como-funiona-o-calculo-dos-quocientes-partidario-e-eleitoral

# Conjuntos de dados
# https://sig.tse.jus.br/ords/dwapr/r/seai/sig-eleicao-arquivo/conjuntos-de-dados?p10_cd_modulo=resultado&session=309649826689846&cs=1iWGX_4kCm1I9RFT7LM3g8OGvjyuhSs0dfNeA6vcgSvnZ5DWoq10rybAKreqCloli3ZA2UxYgg9qMOPODXrRUuA

eleitos_old = pd.read_csv('votacao_candidatos_eleitos.csv', delimiter=';', encoding='latin_1')

votacao_partido_df = pd.read_csv('votacao_partido.csv', delimiter=';', encoding='latin_1')

votacao_df = pd.read_csv('votacao_candidato.csv', delimiter=';', encoding='latin_1')

# %%
# Subtraindo a quantidade de votos da deputada do total de votos válidos
votacao_df['Votos válidos'] = votacao_df['Votos válidos'].apply(
    lambda x: x - votacao_df['Votos nominais'].loc[votacao_df['Nome candidato'] == 'CARLA ZAMBELLI SALGADO DE OLIVEIRA'])

# votos Zambelli = 946244

# Eliminando a candidata do quadro de candidatos
votacao_df = votacao_df.drop(votacao_df.loc[votacao_df['Nome candidato'] == 'CARLA ZAMBELLI SALGADO DE OLIVEIRA'].index)

# %% [markdown]
# Precisamos agora calcular a nova divisão de vagas entre os partidos

# %%
votacao_partido_df['Quantidade de votos válidos'].loc[votacao_partido_df['Sigla partido'] == 'PL']

# O partido PL obteve 5343667 votos, subtraindo o número de votos da candidata do total, temos 4397423
votos_pl = 5343667 - 946244

# Atribuindo a nova quantidade de votos válidos ao partido da candidata
votacao_partido_df['Quantidade de votos válidos'].loc[votacao_partido_df['Sigla partido'] == 'PL'] = votos_pl
votacao_partido_df
# Out:
# /tmp/ipykernel_4430/530472566.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['Quantidade de votos válidos'].loc[votacao_partido_df['Sigla partido'] == 'PL'] = votos_pl
# /tmp/ipykernel_4430/530472566.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['Quantidade de votos válidos'].loc[votacao_partido_df['Sigla partido'] == 'PL'] = votos_pl
#     Ano de eleição             Cargo  UF        Coligação  \
# 0             2022  Deputado Federal  SP        FEDERAÇÃO
# 1             2022  Deputado Federal  SP        FEDERAÇÃO
# 2             2022  Deputado Federal  SP        FEDERAÇÃO
# 3             2022  Deputado Federal  SP        FEDERAÇÃO
# 4             2022  Deputado Federal  SP        FEDERAÇÃO
# 5             2022  Deputado Federal  SP        FEDERAÇÃO
# 6             2022  Deputado Federal  SP        FEDERAÇÃO
# 7             2022  Deputado Federal  SP  PARTIDO ISOLADO
# 8             2022  Deputado Federal  SP  PARTIDO ISOLADO
# 9             2022  Deputado Federal  SP  PARTIDO ISOLADO
# 10            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 11            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 12            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 13            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 14            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 15            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 16            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 17            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 18            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 19            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 20            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 21            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 22            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 23            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 24            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 25            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 26            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 27            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 28            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 29            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 30            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 31            2022  Deputado Federal  SP  PARTIDO ISOLADO
#
#    Composição da federação   Região Sigla da federação  Sigla partido  Turno  \
# 0         CIDADANIA / PSDB  SUDESTE     PSDB/CIDADANIA      CIDADANIA      1
# 1         CIDADANIA / PSDB  SUDESTE     PSDB/CIDADANIA           PSDB      1
# 2        PC do B / PT / PV  SUDESTE      PT/PC do B/PV        PC do B      1
# 3        PC do B / PT / PV  SUDESTE      PT/PC do B/PV             PT      1
# 4        PC do B / PT / PV  SUDESTE      PT/PC do B/PV             PV      1
# 5              PSOL / REDE  SUDESTE          PSOL/REDE           PSOL      1
# 6              PSOL / REDE  SUDESTE          PSOL/REDE           REDE      1
# 7                   #NULO#  SUDESTE             #NULO#           AGIR      1
# 8                   #NULO#  SUDESTE             #NULO#         AVANTE      1
# 9                   #NULO#  SUDESTE             #NULO#             DC      1
# 10                  #NULO#  SUDESTE             #NULO#            MDB      1
# 11                  #NULO#  SUDESTE             #NULO#           NOVO      1
# 12                  #NULO#  SUDESTE             #NULO#       PATRIOTA      1
# 13                  #NULO#  SUDESTE             #NULO#            PCB      1
# 14                  #NULO#  SUDESTE             #NULO#            PCO      1
# 15                  #NULO#  SUDESTE             #NULO#            PDT      1
# 16                  #NULO#  SUDESTE             #NULO#             PL      1
# 17                  #NULO#  SUDESTE             #NULO#            PMB      1
# 18                  #NULO#  SUDESTE             #NULO#            PMN      1
# 19                  #NULO#  SUDESTE             #NULO#           PODE      1
# 20                  #NULO#  SUDESTE             #NULO#             PP      1
# 21                  #NULO#  SUDESTE             #NULO#           PROS      1
# 22                  #NULO#  SUDESTE             #NULO#           PRTB      1
# 23                  #NULO#  SUDESTE             #NULO#            PSB      1
# 24                  #NULO#  SUDESTE             #NULO#            PSC      1
# 25                  #NULO#  SUDESTE             #NULO#            PSD      1
# 26                  #NULO#  SUDESTE             #NULO#           PSTU      1
# 27                  #NULO#  SUDESTE             #NULO#            PTB      1
# 28                  #NULO#  SUDESTE             #NULO#   REPUBLICANOS      1
# 29                  #NULO#  SUDESTE             #NULO#  SOLIDARIEDADE      1
# 30                  #NULO#  SUDESTE             #NULO#          UNIÃO      1
# 31                  #NULO#  SUDESTE             #NULO#             UP      1
#
#     Quantidade de votos válidos        Data de carga
# 0                        438574  2025-03-25 03:36:58
# 1                       1061538  2025-03-25 03:36:58
# 2                        145727  2025-03-25 03:36:58
# 3                       2941086  2025-03-25 03:36:58
# 4                         45794  2025-03-25 03:36:58
# 5                       1984281  2025-03-25 03:36:58
# 6                        304580  2025-03-25 03:36:58
# 7                         33343  2025-03-25 03:36:58
# 8                        241814  2025-03-25 03:36:58
# 9                          5269  2025-03-25 03:36:58
# 10                      1613626  2025-03-25 03:36:58
# 11                       361268  2025-03-25 03:36:58
# 12                       228947  2025-03-25 03:36:58
# 13                        15510  2025-03-25 03:36:58
# 14                         4187  2025-03-25 03:36:58
# 15                       285898  2025-03-25 03:36:58
# 16                      4397423  2025-03-25 03:36:58
# 17                        18698  2025-03-25 03:36:58
# 18                        15463  2025-03-25 03:36:58
# 19                       892443  2025-03-25 03:36:58
# 20                      1174646  2025-03-25 03:36:58
# 21                        60576  2025-03-25 03:36:58
# 22                        54545  2025-03-25 03:36:58
# 23                       733141  2025-03-25 03:36:58
# 24                       293192  2025-03-25 03:36:58
# 25                      1055965  2025-03-25 03:36:58
# 26                         8790  2025-03-25 03:36:58
# 27                       217212  2025-03-25 03:36:58
# 28                      1580891  2025-03-25 03:36:58
# 29                       379310  2025-03-25 03:36:58
# 30                      1811462  2025-03-25 03:36:58
# 31                        24142  2025-03-25 03:36:58

# %%
# São 70 vagas para Deputado Federal, precisamos também recalcular o quociente eleitoral
# 22429341 / 70 = 320420
quociente_eleitoral = 22429341 / 70

# Calculando o novo quociente partidário
votacao_partido_df = votacao_partido_df.assign(quociente_partidario=lambda x: x['Quantidade de votos válidos'] // quociente_eleitoral)

# 58 vagas foram preenchidas através do quociente partidário, restando 12 vagas para cálculo das sobras
votacao_partido_df['quociente_partidario'].sum()
# Out:
# np.float64(58.0)

# %%
# Esse loop executa o cálculo da média do partido, altera o valor do quociente partidário faz 
# o cálculo da nova média a cada inserção na média partidária, preenchendo  então as 12 vagas de 'sobras'
for i in range(59, 70+1):
    
    # Média mínima para concorrer as vagas de 'sobras' deve ser de pelo menos 80% do quociente eleitoral
    # 320420 * 0,8
    media_minima = quociente_eleitoral * 0.8

    # Cria nova coluna com a média dos partidos
    votacao_partido_df = votacao_partido_df.assign(media_sobra=lambda x: x['Quantidade de votos válidos'] / (x['quociente_partidario'] + 1))

    # Partido com a maior média
    vaga_sobra = votacao_partido_df['Sigla partido'].loc[votacao_partido_df['media_sobra'].idxmax()]
    media_partido = votacao_partido_df['media_sobra'].max()
    
    # Apenas os partidos que alcançaram 80% do quociente eleitoral concorrem as vagas de 'sobras'
    if media_partido > media_minima:
        
        # Atualizando o quociente partidário para acrescentar o número de vagas de 'sobras'
        votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# Out:
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)
# /tmp/ipykernel_4430/553525165.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra] = votacao_partido_df['quociente_partidario'].loc[votacao_partido_df['Sigla partido'] == vaga_sobra].apply(lambda x: x + 1)

# %%
# Divisão final das vagas entre os partidos
votacao_partido_df['quociente_partidario'] = votacao_partido_df['quociente_partidario'].astype('int')
votacao_partido_df
# Out:
#     Ano de eleição             Cargo  UF        Coligação  \
# 0             2022  Deputado Federal  SP        FEDERAÇÃO
# 1             2022  Deputado Federal  SP        FEDERAÇÃO
# 2             2022  Deputado Federal  SP        FEDERAÇÃO
# 3             2022  Deputado Federal  SP        FEDERAÇÃO
# 4             2022  Deputado Federal  SP        FEDERAÇÃO
# 5             2022  Deputado Federal  SP        FEDERAÇÃO
# 6             2022  Deputado Federal  SP        FEDERAÇÃO
# 7             2022  Deputado Federal  SP  PARTIDO ISOLADO
# 8             2022  Deputado Federal  SP  PARTIDO ISOLADO
# 9             2022  Deputado Federal  SP  PARTIDO ISOLADO
# 10            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 11            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 12            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 13            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 14            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 15            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 16            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 17            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 18            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 19            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 20            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 21            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 22            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 23            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 24            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 25            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 26            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 27            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 28            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 29            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 30            2022  Deputado Federal  SP  PARTIDO ISOLADO
# 31            2022  Deputado Federal  SP  PARTIDO ISOLADO
#
#    Composição da federação   Região Sigla da federação  Sigla partido  Turno  \
# 0         CIDADANIA / PSDB  SUDESTE     PSDB/CIDADANIA      CIDADANIA      1
# 1         CIDADANIA / PSDB  SUDESTE     PSDB/CIDADANIA           PSDB      1
# 2        PC do B / PT / PV  SUDESTE      PT/PC do B/PV        PC do B      1
# 3        PC do B / PT / PV  SUDESTE      PT/PC do B/PV             PT      1
# 4        PC do B / PT / PV  SUDESTE      PT/PC do B/PV             PV      1
# 5              PSOL / REDE  SUDESTE          PSOL/REDE           PSOL      1
# 6              PSOL / REDE  SUDESTE          PSOL/REDE           REDE      1
# 7                   #NULO#  SUDESTE             #NULO#           AGIR      1
# 8                   #NULO#  SUDESTE             #NULO#         AVANTE      1
# 9                   #NULO#  SUDESTE             #NULO#             DC      1
# 10                  #NULO#  SUDESTE             #NULO#            MDB      1
# 11                  #NULO#  SUDESTE             #NULO#           NOVO      1
# 12                  #NULO#  SUDESTE             #NULO#       PATRIOTA      1
# 13                  #NULO#  SUDESTE             #NULO#            PCB      1
# 14                  #NULO#  SUDESTE             #NULO#            PCO      1
# 15                  #NULO#  SUDESTE             #NULO#            PDT      1
# 16                  #NULO#  SUDESTE             #NULO#             PL      1
# 17                  #NULO#  SUDESTE             #NULO#            PMB      1
# 18                  #NULO#  SUDESTE             #NULO#            PMN      1
# 19                  #NULO#  SUDESTE             #NULO#           PODE      1
# 20                  #NULO#  SUDESTE             #NULO#             PP      1
# 21                  #NULO#  SUDESTE             #NULO#           PROS      1
# 22                  #NULO#  SUDESTE             #NULO#           PRTB      1
# 23                  #NULO#  SUDESTE             #NULO#            PSB      1
# 24                  #NULO#  SUDESTE             #NULO#            PSC      1
# 25                  #NULO#  SUDESTE             #NULO#            PSD      1
# 26                  #NULO#  SUDESTE             #NULO#           PSTU      1
# 27                  #NULO#  SUDESTE             #NULO#            PTB      1
# 28                  #NULO#  SUDESTE             #NULO#   REPUBLICANOS      1
# 29                  #NULO#  SUDESTE             #NULO#  SOLIDARIEDADE      1
# 30                  #NULO#  SUDESTE             #NULO#          UNIÃO      1
# 31                  #NULO#  SUDESTE             #NULO#             UP      1
#
#     Quantidade de votos válidos        Data de carga  quociente_partidario  \
# 0                        438574  2025-03-25 03:36:58                     1
# 1                       1061538  2025-03-25 03:36:58                     3
# 2                        145727  2025-03-25 03:36:58                     0
# 3                       2941086  2025-03-25 03:36:58                    10
# 4                         45794  2025-03-25 03:36:58                     0
# 5                       1984281  2025-03-25 03:36:58                     7
# 6                        304580  2025-03-25 03:36:58                     1
# 7                         33343  2025-03-25 03:36:58                     0
# 8                        241814  2025-03-25 03:36:58                     0
# 9                          5269  2025-03-25 03:36:58                     0
# 10                      1613626  2025-03-25 03:36:58                     5
# 11                       361268  2025-03-25 03:36:58                     1
# 12                       228947  2025-03-25 03:36:58                     0
# 13                        15510  2025-03-25 03:36:58                     0
# 14                         4187  2025-03-25 03:36:58                     0
# 15                       285898  2025-03-25 03:36:58                     1
# 16                      4397423  2025-03-25 03:36:58                    16
# 17                        18698  2025-03-25 03:36:58                     0
# 18                        15463  2025-03-25 03:36:58                     0
# 19                       892443  2025-03-25 03:36:58                     3
# 20                      1174646  2025-03-25 03:36:58                     4
# 21                        60576  2025-03-25 03:36:58                     0
# 22                        54545  2025-03-25 03:36:58                     0
# 23                       733141  2025-03-25 03:36:58                     2
# 24                       293192  2025-03-25 03:36:58                     1
# 25                      1055965  2025-03-25 03:36:58                     3
# 26                         8790  2025-03-25 03:36:58                     0
# 27                       217212  2025-03-25 03:36:58                     0
# 28                      1580891  2025-03-25 03:36:58                     5
# 29                       379310  2025-03-25 03:36:58                     1
# 30                      1811462  2025-03-25 03:36:58                     6
# 31                        24142  2025-03-25 03:36:58                     0
#
#       media_sobra
# 0   219287.000000
# 1   265384.500000
# 2   145727.000000
# 3   267371.454545
# 4    45794.000000
# 5   248035.125000
# 6   152290.000000
# 7    33343.000000
# 8   241814.000000
# 9     5269.000000
# 10  268937.666667
# 11  180634.000000
# 12  228947.000000
# 13   15510.000000
# 14    4187.000000
# 15  142949.000000
# 16  274838.937500
# 17   18698.000000
# 18   15463.000000
# 19  223110.750000
# 20  234929.200000
# 21   60576.000000
# 22   54545.000000
# 23  244380.333333
# 24  146596.000000
# 25  263991.250000
# 26    8790.000000
# 27  217212.000000
# 28  263481.833333
# 29  189655.000000
# 30  258780.285714
# 31   24142.000000

# %% [markdown]
# com o quadro de vagas por partido em mãos, vamos agora preencher as cadeiras com os candidatos eleitos

# %%
# Aplicando ordem decrescente por votos nominais
votacao_df = votacao_df.sort_values(by='Votos nominais', ascending=False)
votacao_df.loc[votacao_df['Partido'] == 'PSOL'].head(5)
# Out:
#       Ano de eleição             Cargo  UF                    Nome candidato  \
# 1415            2022  Deputado Federal  SP           GUILHERME CASTRO BOULOS
# 460             2022  Deputado Federal  SP                ERIKA SANTOS SILVA
# 35              2022  Deputado Federal  SP             SÂMIA DE SOUZA BOMFIM
# 1337            2022  Deputado Federal  SP  SÔNIA BONE DE SOUSA SILVA SANTOS
# 561             2022  Deputado Federal  SP           LUIZA ERUNDINA DE SOUSA
#
#       Número candidato Partido     Gênero  Votos válidos  Votos nominais  \
# 1415              5010    PSOL  Masculino       22429341         1001472
# 460               5070    PSOL   Feminino       22429341          256903
# 35                5000    PSOL   Feminino       22429341          226187
# 1337              5088    PSOL   Feminino       22429341          156966
# 561               5021    PSOL   Feminino       22429341          113983
#
#             Data de carga
# 1415  2025-03-25 03:36:58
# 460   2025-03-25 03:36:58
# 35    2025-03-25 03:36:58
# 1337  2025-03-25 03:36:58
# 561   2025-03-25 03:36:58

# %%
# Renomeia a coluna para posterior mesclagem
votacao_partido_df = votacao_partido_df.rename(columns={'Sigla partido':'Partido'})

# Mesclando os dois dataframes
merge_df = votacao_df.merge(votacao_partido_df, on='Partido')

# Eliminando os candidados que obtiveram menos de 10% do quociente eleitoral
merge_df = merge_df.drop(merge_df.loc[merge_df['Votos nominais'] < (quociente_eleitoral * 0.1)].index)

merge_df.loc[merge_df['Votos nominais'] < (quociente_eleitoral * 0.1)].index
# Out:
# Index([], dtype='int64')

# %%
# Agrupa os candidatos por Partido, ordena os candidatos 
# com maior número de votos e filtra o número de candidatos
# de acordo com o quociente partidário
eleitos_new = merge_df.groupby(by=['Partido']).apply(lambda x: x.nlargest(int(x['quociente_partidario'].mean()), 'Votos nominais'))
# Out:
# /tmp/ipykernel_4430/1782090286.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   eleitos_new = merge_df.groupby(by=['Partido']).apply(lambda x: x.nlargest(int(x['quociente_partidario'].mean()), 'Votos nominais'))

# %%
eleitos_new.to_csv('candidatos_eleitos.csv', index=False)

# %%
# dataframe com os deputados eleitos antes da deputada perder seu mandato
eleitos_old = eleitos_old.drop(eleitos_old.loc[eleitos_old['ds_sit_totalizacao'] != 'Eleito'].index)

# %%
# Mescla os dois dataframes e indica sua diferença simétrica
eleitos_old = eleitos_old.rename(columns={'nm_candidato': 'Nome candidato'})

resultado = eleitos_new.merge(eleitos_old, how='outer', indicator=True)

# %%
# Excluindo tabelas irrelevantes
resultado = resultado[['Nome candidato', 'Partido', 'Votos nominais', '_merge']]
resultado.to_csv('resultado.csv', index=False)

# %%
perdeu_mandato = resultado['Nome candidato'].loc[resultado['_merge'] == 'right_only']
ganhou_mandato = resultado['Nome candidato'].loc[resultado['_merge'] == 'left_only']

print(f'Perdeu mandato:\n{perdeu_mandato.tolist()}')
print(f'\nGanhou mandato:\n{ganhou_mandato.tolist()}')
# Out:
# Perdeu mandato:
# ['ARNALDO CALIL PEREIRA JARDIM', 'CARLA ZAMBELLI SALGADO DE OLIVEIRA', 'LUIZ PAULO TEIXEIRA FERREIRA']
#
# Ganhou mandato:
# ['IVAN VALENTE', 'LUCIENE CAVALCANTE DA SILVA', 'WESLEY LEONARDO CEZAR']
